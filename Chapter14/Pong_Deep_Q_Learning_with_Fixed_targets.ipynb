# %% [markdown]
# <a href="https://colab.research.google.com/github/regmiresearch/ImageProcessingProjects/blob/main/Chapter14/Pong_Deep_Q_Learning_with_Fixed_targets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install "gymnasium[atari,accept-rom-license]"
# Out:
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /usr/local/lib/python3.12/dist-packages (1.3.0)
# WARNING: gymnasium 1.3.0 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.0.6)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.12.0)

# %%
# %pip install autorom[accept-rom-license]
# Out:
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (8.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (2.32.4)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 25.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2026.5.20)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=41ca510abfb978befeec0a257b59165aad864a5143b321171b070a82ed4f6f29
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.6.1

# %%
import gymnasium as gym
import numpy as np
import ale_py
import cv2
from collections import deque
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
from collections import namedtuple, deque
import torch
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# env = gym.make('PongDeterministic-v0')
# Change this:
# env = gym.make('PongDeterministic-v0')

# To this:
env = gym.make('ALE/Pong-v5', repeat_action_probability=0.0)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %%
def preprocess_frame(frame):
    bkg_color = np.array([144, 72, 17])
    img = np.mean(frame[34:-16:2,::2]-bkg_color, axis=-1)/255.
    resized_image = img
    return resized_image

# %%
def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess_frame(state)
    stack_size = 4
    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((80,80), dtype=np.uint8) for i in range(stack_size)], maxlen=4)
        # Because we're in a new episode, copy the same frame 4x
        for i in range(stack_size):
            stacked_frames.append(frame)
        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2).transpose(2, 0, 1)
    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)
        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2).transpose(2, 0, 1)
    return stacked_state, stacked_frames


class DQNetwork(nn.Module):
    def __init__(self, states, action_size):
        super(DQNetwork, self).__init__()

        self.conv1 = nn.Conv2d(4, 32, (8, 8), stride=4)
        self.conv2 = nn.Conv2d(32, 64, (4, 4), stride=2)
        self.conv3 = nn.Conv2d(64, 64, (3, 3), stride=1)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(2304, 512)
        self.fc2 = nn.Linear(512, action_size)

    def forward(self, state):
        x = F.relu(self.conv1(state))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
class Agent():
    def __init__(self, state_size, action_size):

        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(0)

        ## hyperparameters
        self.buffer_size = 1000
        self.batch_size = 32
        self.gamma = 0.99
        self.lr = 0.0001
        self.update_every = 4
        self.update_every_target = 1000
        self.learn_every_target_counter = 0
        # Q-Network
        self.local = DQNetwork(state_size, action_size).to(device)
        self.target = DQNetwork(state_size, action_size).to(device)
        self.optimizer = optim.Adam(self.local.parameters(), lr=self.lr)

        # Replay memory
        self.memory = deque(maxlen=self.buffer_size)
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        # Initialize time step (for updating every few steps)
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.append(self.experience(state[None], action, reward, next_state[None], done))

        # Learn every update_every time steps.
        self.t_step = (self.t_step + 1) % self.update_every
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > self.batch_size:
                experiences = self.sample_experiences()
                self.learn(experiences, self.gamma)

    def act(self, state, eps=0.):
        # Epsilon-greedy action selection
        if random.random() > eps:
            state = torch.from_numpy(state).float().unsqueeze(0).to(device)
            self.local.eval()
            with torch.no_grad():
                action_values = self.local(state)
            self.local.train()
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        self.learn_every_target_counter+=1
        states, actions, rewards, next_states, dones = experiences
       # Get expected Q values from local model
        Q_expected = self.local(states).gather(1, actions)

        # Get max predicted Q values (for next states) from target model
        Q_targets_next = self.target(next_states).detach().max(1)[0].unsqueeze(1)
        # Compute Q targets for current state
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))

        # Compute loss
        loss = F.mse_loss(Q_expected, Q_targets)

        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # ------------------- update target network ------------------- #
        if self.learn_every_target_counter%1000 ==0:
            self.target_update()

    def target_update(self):
        print('\ntarget updating')
        self.target.load_state_dict(self.local.state_dict())

    def sample_experiences(self):
        experiences = random.sample(self.memory, k=self.batch_size)
        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
        return (states, actions, rewards, next_states, dones)

agent = Agent(state_size, action_size)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
n_episodes=5000
max_t=5000
eps_start=1.0
eps_end=0.02
eps_decay=0.995
scores = [] # list containing scores from each episode
scores_window = deque(maxlen=100) # last 100 scores
eps = eps_start
stack_size = 4
stacked_frames = deque([np.zeros((80,80), dtype=int) for i in range(stack_size)], maxlen=stack_size)

# %%
for i_episode in range(1, n_episodes+1):
    state = env.reset()
    state, _ = state
    state, frames = stack_frames(stacked_frames, state, True)
    score = 0
    for i in range(max_t):
        action = agent.act(state, eps)
        next_state, reward, done, *_ = env.step(action)
        next_state, frames = stack_frames(frames, next_state, False)
        agent.step(state, action, reward, next_state, done)
        state = next_state
        score += reward
        if done:
            break
    scores_window.append(score) # save most recent score
    scores.append(score) # save most recent score
    eps = max(eps_end, eps_decay*eps) # decrease epsilon
    print('\rEpisode {}\tReward {} \tAverage Score: {:.2f} \tEpsilon: {}'.format(i_episode,score,np.mean(scores_window), eps), end="")
    if i_episode % 100 == 0:
        print('\rEpisode {}\tAverage Score: {:.2f} \tEpsilon: {}'.format(i_episode, np.mean(scores_window), eps))
# Out:
# Episode 4	Reward -20.0 	Average Score: -20.75 	Epsilon: 0.9801495006250001
# target updating
# Episode 8	Reward -21.0 	Average Score: -20.75 	Epsilon: 0.960693043575437
# target updating
# Episode 13	Reward -20.0 	Average Score: -20.62 	Epsilon: 0.9369146928798039
# target updating
# Episode 17	Reward -21.0 	Average Score: -20.65 	Epsilon: 0.918316468354365
# target updating
# Episode 21	Reward -20.0 	Average Score: -20.62 	Epsilon: 0.9000874278732445
# target updating
# Episode 25	Reward -20.0 	Average Score: -20.52 	Epsilon: 0.8822202429488013
# target updating
# Episode 30	Reward -21.0 	Average Score: -20.57 	Epsilon: 0.8603841919146962
# target updating
# Episode 34	Reward -21.0 	Average Score: -20.59 	Epsilon: 0.8433051360508336
# target updating
# Episode 39	Reward -21.0 	Average Score: -20.64 	Epsilon: 0.8224322824348486
# target updating
# Episode 43	Reward -21.0 	Average Score: -20.63 	Epsilon: 0.8061065909263957
# target updating
# Episode 47	Reward -18.0 	Average Score: -20.55 	Epsilon: 0.7901049725470279
# target updating
# Episode 52	Reward -21.0 	Average Score: -20.54 	Epsilon: 0.7705488893118823
# target updating
# Episode 56	Reward -21.0 	Average Score: -20.54 	Epsilon: 0.7552531090661897
# target updating
# Episode 60	Reward -20.0 	Average Score: -20.55 	Epsilon: 0.7402609576967045
# target updating
# Episode 65	Reward -21.0 	Average Score: -20.55 	Epsilon: 0.7219385759785162
# target updating
# Episode 69	Reward -21.0 	Average Score: -20.54 	Epsilon: 0.7076077347272662
# target updating
# Episode 73	Reward -19.0 	Average Score: -20.48 	Epsilon: 0.6935613678313175
# target updating
# Episode 76	Reward -19.0 	Average Score: -20.46 	Epsilon: 0.6832098777212641
# target updating
# Episode 80	Reward -20.0 	Average Score: -20.45 	Epsilon: 0.6696478204705644
# target updating
# Episode 84	Reward -21.0 	Average Score: -20.44 	Epsilon: 0.6563549768288433
# target updating
# Episode 88	Reward -21.0 	Average Score: -20.43 	Epsilon: 0.6433260027715241
# target updating
# Episode 92	Reward -19.0 	Average Score: -20.42 	Epsilon: 0.6305556603555866
# target updating
# Episode 96	Reward -21.0 	Average Score: -20.43 	Epsilon: 0.6180388156137953
# target updating
# Episode 99	Reward -20.0 	Average Score: -20.40 	Epsilon: 0.6088145090359074
# target updating
# Episode 100	Average Score: -20.40 	Epsilon: 0.6057704364907278
# Episode 103	Reward -18.0 	Average Score: -20.35 	Epsilon: 0.5967292370047992
# target updating
# Episode 106	Reward -20.0 	Average Score: -20.35 	Epsilon: 0.5878229785513479
# target updating
# Episode 110	Reward -20.0 	Average Score: -20.30 	Epsilon: 0.5761543988830038
# target updating
# Episode 113	Reward -20.0 	Average Score: -20.28 	Epsilon: 0.567555222460375
# target updating
# Episode 117	Reward -19.0 	Average Score: -20.23 	Epsilon: 0.5562889678716474
# target updating
# Episode 121	Reward -20.0 	Average Score: -20.24 	Epsilon: 0.5452463540625918
# target updating
# Episode 124	Reward -21.0 	Average Score: -20.26 	Epsilon: 0.5371084840724134
# target updating
# Episode 127	Reward -21.0 	Average Score: -20.24 	Epsilon: 0.5290920728090721
# target updating
# Episode 130	Reward -16.0 	Average Score: -20.17 	Epsilon: 0.5211953074858876
# target updating
# Episode 133	Reward -19.0 	Average Score: -20.10 	Epsilon: 0.5134164023722473
# target updating
# Episode 136	Reward -21.0 	Average Score: -20.08 	Epsilon: 0.5057535983897912
# target updating
# Episode 139	Reward -20.0 	Average Score: -20.04 	Epsilon: 0.4982051627146237
# target updating
# Episode 142	Reward -17.0 	Average Score: -19.98 	Epsilon: 0.4907693883854626
# target updating
# Episode 145	Reward -20.0 	Average Score: -19.92 	Epsilon: 0.483444593917636
# target updating
# Episode 148	Reward -18.0 	Average Score: -19.88 	Epsilon: 0.47622912292284103
# target updating
# Episode 151	Reward -17.0 	Average Score: -19.81 	Epsilon: 0.46912134373457726
# target updating
# Episode 154	Reward -18.0 	Average Score: -19.75 	Epsilon: 0.46211964903917074
# target updating
# Episode 157	Reward -20.0 	Average Score: -19.71 	Epsilon: 0.45522245551230495
# target updating
# Episode 160	Reward -18.0 	Average Score: -19.65 	Epsilon: 0.4484282034609769
# target updating
# Episode 163	Reward -17.0 	Average Score: -19.63 	Epsilon: 0.4417353564707963
# target updating
# Episode 165	Reward -17.0 	Average Score: -19.57 	Epsilon: 0.43732904629000013
# target updating
# Episode 168	Reward -17.0 	Average Score: -19.49 	Epsilon: 0.43080185560799106
# target updating
# Episode 171	Reward -20.0 	Average Score: -19.48 	Epsilon: 0.42437208406280985
# target updating
# Episode 173	Reward -18.0 	Average Score: -19.47 	Epsilon: 0.42013897252428334
# target updating
# Episode 176	Reward -20.0 	Average Score: -19.43 	Epsilon: 0.41386834584198684
# target updating
# Episode 178	Reward -17.0 	Average Score: -19.37 	Epsilon: 0.40974000909221303
# target updating
# Episode 181	Reward -17.0 	Average Score: -19.33 	Epsilon: 0.4036245882390106
# target updating
# Episode 184	Reward -16.0 	Average Score: -19.22 	Epsilon: 0.3976004408064698
# target updating
# Episode 186	Reward -18.0 	Average Score: -19.18 	Epsilon: 0.3936343764094253
# target updating
# Episode 188	Reward -18.0 	Average Score: -19.12 	Epsilon: 0.3897078735047413
# target updating
# Episode 191	Reward -15.0 	Average Score: -19.02 	Epsilon: 0.38389143477919885
# target updating
# Episode 193	Reward -19.0 	Average Score: -19.00 	Epsilon: 0.3800621177172763
# target updating
# Episode 196	Reward -18.0 	Average Score: -18.96 	Epsilon: 0.3743896431025813
# target updating
# Episode 199	Reward -19.0 	Average Score: -18.95 	Epsilon: 0.36880183088056995
# target updating
# Episode 200	Average Score: -18.91 	Epsilon: 0.3669578217261671
# Episode 201	Reward -20.0 	Average Score: -18.91 	Epsilon: 0.36512303261753626
# target updating
# Episode 204	Reward -18.0 	Average Score: -18.83 	Epsilon: 0.3596735257153405
# target updating
# Episode 206	Reward -18.0 	Average Score: -18.81 	Epsilon: 0.35608578229633
# target updating
# Episode 209	Reward -15.0 	Average Score: -18.77 	Epsilon: 0.3507711574848344
# target updating
# Episode 211	Reward -19.0 	Average Score: -18.76 	Epsilon: 0.3472722151889232
# target updating
# Episode 213	Reward -18.0 	Average Score: -18.71 	Epsilon: 0.3438081748424137
# target updating
# Episode 216	Reward -14.0 	Average Score: -18.61 	Epsilon: 0.3386767948568688
# target updating
# Episode 218	Reward -18.0 	Average Score: -18.56 	Epsilon: 0.3352984938281715
# target updating
# Episode 220	Reward -18.0 	Average Score: -18.49 	Epsilon: 0.33195389135223546
# target updating
# Episode 222	Reward -17.0 	Average Score: -18.46 	Epsilon: 0.32864265128599696
# target updating
# Episode 224	Reward -14.0 	Average Score: -18.35 	Epsilon: 0.3253644408394192
# target updating
# Episode 226	Reward -17.0 	Average Score: -18.27 	Epsilon: 0.322118930542046
# target updating
# Episode 228	Reward -14.0 	Average Score: -18.17 	Epsilon: 0.31890579420988907
# target updating
# Episode 230	Reward -12.0 	Average Score: -18.11 	Epsilon: 0.3157247089126454
# target updating
# Episode 232	Reward -16.0 	Average Score: -18.07 	Epsilon: 0.3125753549412418
# target updating
# Episode 234	Reward -14.0 	Average Score: -17.99 	Epsilon: 0.30945741577570285
# target updating
# Episode 236	Reward -11.0 	Average Score: -17.87 	Epsilon: 0.3063705780533402
# target updating
# Episode 238	Reward -17.0 	Average Score: -17.82 	Epsilon: 0.3033145315372582
# target updating
# Episode 240	Reward -20.0 	Average Score: -17.78 	Epsilon: 0.30028896908517405
# target updating
# Episode 241	Reward -14.0 	Average Score: -17.73 	Epsilon: 0.2987875242397482
# target updating
# Episode 244	Reward -19.0 	Average Score: -17.74 	Epsilon: 0.2943280830920294
# target updating
# Episode 246	Reward -17.0 	Average Score: -17.69 	Epsilon: 0.2913921604631864
# target updating
# Episode 248	Reward -17.0 	Average Score: -17.72 	Epsilon: 0.2884855236625661
# target updating
# Episode 250	Reward -14.0 	Average Score: -17.66 	Epsilon: 0.285607880564032
# target updating
# Episode 252	Reward -18.0 	Average Score: -17.58 	Epsilon: 0.2827589419554058
# target updating
# Episode 254	Reward -19.0 	Average Score: -17.57 	Epsilon: 0.2799384215094006
# target updating
# Episode 256	Reward -18.0 	Average Score: -17.54 	Epsilon: 0.27714603575484437
# target updating
# Episode 258	Reward -19.0 	Average Score: -17.49 	Epsilon: 0.2743815040481898
# target updating
# Episode 261	Reward -20.0 	Average Score: -17.42 	Epsilon: 0.2702863258025825
# target updating
# Episode 263	Reward -17.0 	Average Score: -17.42 	Epsilon: 0.26759021970270175
# target updating
# Episode 265	Reward -16.0 	Average Score: -17.39 	Epsilon: 0.2649210072611673
# target updating
# Episode 267	Reward -18.0 	Average Score: -17.36 	Epsilon: 0.26227842021373715
# target updating
# Episode 269	Reward -19.0 	Average Score: -17.36 	Epsilon: 0.25966219297210513
# target updating
# Episode 271	Reward -13.0 	Average Score: -17.25 	Epsilon: 0.2570720625972084
# target updating
# Episode 273	Reward -7.0 	Average Score: -17.06 	Epsilon: 0.25450776877280124
# target updating
# Episode 274	Reward -11.0 	Average Score: -17.01 	Epsilon: 0.2532352299289372
# target updating
# Episode 276	Reward -20.0 	Average Score: -16.96 	Epsilon: 0.2507092085103961
# target updating
# Episode 278	Reward -10.0 	Average Score: -16.84 	Epsilon: 0.24820838415550486
# target updating
# Episode 280	Reward -17.0 	Average Score: -16.76 	Epsilon: 0.2457325055235537
# target updating
# Episode 282	Reward -14.0 	Average Score: -16.72 	Epsilon: 0.24328132378095624
# target updating
# Episode 284	Reward -15.0 	Average Score: -16.71 	Epsilon: 0.2408545925762412
# target updating
# Episode 286	Reward -16.0 	Average Score: -16.67 	Epsilon: 0.2384520680152932
# target updating
# Episode 287	Reward -19.0 	Average Score: -16.68 	Epsilon: 0.23725980767521673
# target updating
# Episode 289	Reward -12.0 	Average Score: -16.60 	Epsilon: 0.23489314109365644
# target updating
# Episode 291	Reward -17.0 	Average Score: -16.58 	Epsilon: 0.23255008201124722
# target updating
# Episode 293	Reward -15.0 	Average Score: -16.45 	Epsilon: 0.23023039494318503
# target updating
# Episode 295	Reward -14.0 	Average Score: -16.36 	Epsilon: 0.22793384675362674
# target updating
# Episode 297	Reward -17.0 	Average Score: -16.33 	Epsilon: 0.22566020663225933
# target updating
# Episode 298	Reward -11.0 	Average Score: -16.25 	Epsilon: 0.22453190559909803
# target updating
# Episode 300	Average Score: -16.24 	Epsilon: 0.22229219984074702
#
# target updating
# Episode 302	Reward -19.0 	Average Score: -16.23 	Epsilon: 0.22007483514733558
# target updating
# Episode 304	Reward -16.0 	Average Score: -16.22 	Epsilon: 0.2178795886667409
# target updating
# Episode 306	Reward -17.0 	Average Score: -16.02 	Epsilon: 0.21570623976979014
# target updating
# Episode 308	Reward -15.0 	Average Score: -15.97 	Epsilon: 0.21355457002808648
# target updating
# Episode 310	Reward -17.0 	Average Score: -15.96 	Epsilon: 0.21142436319205632
# target updating
# Episode 311	Reward -11.0 	Average Score: -15.88 	Epsilon: 0.21036724137609603
# target updating
# Episode 313	Reward -19.0 	Average Score: -15.87 	Epsilon: 0.20826882814336947
# target updating
# Episode 315	Reward -14.0 	Average Score: -15.82 	Epsilon: 0.20619134658263935
# target updating
# Episode 318	Reward -16.0 	Average Score: -15.83 	Epsilon: 0.2031139149609751
# target updating
# Episode 320	Reward -19.0 	Average Score: -15.82 	Epsilon: 0.2010878536592394
# target updating
# Episode 321	Reward -6.0 	Average Score: -15.68 	Epsilon: 0.2000824143909432
# target updating
# Episode 323	Reward -15.0 	Average Score: -15.63 	Epsilon: 0.19808659230739353
# target updating
# Episode 325	Reward -16.0 	Average Score: -15.64 	Epsilon: 0.19611067854912728
# target updating
# Episode 327	Reward -15.0 	Average Score: -15.67 	Epsilon: 0.19415447453059972
# target updating
# Episode 329	Reward -17.0 	Average Score: -15.72 	Epsilon: 0.192217783647157
# target updating
# Episode 331	Reward -12.0 	Average Score: -15.71 	Epsilon: 0.1903004112552766
# target updating
# Episode 332	Reward -14.0 	Average Score: -15.69 	Epsilon: 0.18934890919900021
# target updating
# Episode 334	Reward -14.0 	Average Score: -15.65 	Epsilon: 0.18746015382974018
# target updating
# Episode 336	Reward -18.0 	Average Score: -15.67 	Epsilon: 0.18559023879528855
# target updating
# Episode 337	Reward -16.0 	Average Score: -15.66 	Epsilon: 0.1846622876013121
# target updating
# Episode 339	Reward -18.0 	Average Score: -15.61 	Epsilon: 0.182820281282489
# target updating
# Episode 341	Reward -11.0 	Average Score: -15.52 	Epsilon: 0.18099664897669618
# target updating
# Episode 342	Reward -10.0 	Average Score: -15.47 	Epsilon: 0.1800916657318127
# target updating
# Episode 344	Reward -18.0 	Average Score: -15.40 	Epsilon: 0.17829525136613786
# target updating
# Episode 346	Reward -15.0 	Average Score: -15.33 	Epsilon: 0.17651675623376062
# target updating
# Episode 348	Reward -15.0 	Average Score: -15.28 	Epsilon: 0.17475600159032884
# target updating
# Episode 350	Reward -16.0 	Average Score: -15.29 	Epsilon: 0.1730128104744653
# target updating
# Episode 351	Reward -14.0 	Average Score: -15.33 	Epsilon: 0.17214774642209296
# target updating
# Episode 352	Reward -11.0 	Average Score: -15.26 	Epsilon: 0.1712870076899825
# target updating
# Episode 354	Reward -11.0 	Average Score: -15.10 	Epsilon: 0.16957841978827493
# target updating
# Episode 355	Reward -11.0 	Average Score: -15.04 	Epsilon: 0.16873052768933355
# target updating
# Episode 357	Reward -19.0 	Average Score: -15.05 	Epsilon: 0.16704744067563246
# target updating
# Episode 359	Reward -14.0 	Average Score: -15.00 	Epsilon: 0.16538114245489302
# target updating
# Episode 360	Reward -13.0 	Average Score: -14.98 	Epsilon: 0.16455423674261854
# target updating
# Episode 362	Reward -16.0 	Average Score: -14.88 	Epsilon: 0.16291280823111093
# target updating
# Episode 364	Reward -14.0 	Average Score: -14.84 	Epsilon: 0.16128775296900558
# target updating
# Episode 365	Reward -12.0 	Average Score: -14.80 	Epsilon: 0.16048131420416054
# target updating
# Episode 367	Reward -12.0 	Average Score: -14.73 	Epsilon: 0.15888051309497406
# target updating
# Episode 369	Reward -15.0 	Average Score: -14.65 	Epsilon: 0.1572956799768517
# target updating
# Episode 370	Reward -17.0 	Average Score: -14.65 	Epsilon: 0.15650920157696743
# target updating
# Episode 372	Reward -13.0 	Average Score: -14.63 	Epsilon: 0.1549480222912372
# target updating
# Episode 373	Reward -18.0 	Average Score: -14.74 	Epsilon: 0.15417328217978102
# target updating
# Episode 374	Reward -10.0 	Average Score: -14.73 	Epsilon: 0.1534024157688821
# target updating
# Episode 376	Reward -18.0 	Average Score: -14.72 	Epsilon: 0.1518722266715875
# target updating
# Episode 377	Reward -18.0 	Average Score: -14.78 	Epsilon: 0.15111286553822956
# target updating
# Episode 379	Reward -11.0 	Average Score: -14.74 	Epsilon: 0.14960551470448571
# target updating
# Episode 380	Reward -16.0 	Average Score: -14.73 	Epsilon: 0.14885748713096328
# target updating
# Episode 382	Reward -19.0 	Average Score: -14.76 	Epsilon: 0.1473726336968319
# target updating
# Episode 384	Reward -17.0 	Average Score: -14.77 	Epsilon: 0.14590259167570602
# target updating
# Episode 385	Reward -17.0 	Average Score: -14.79 	Epsilon: 0.1451730787173275
# target updating
# Episode 387	Reward -11.0 	Average Score: -14.72 	Epsilon: 0.14372497725712216
# target updating
# Episode 388	Reward -14.0 	Average Score: -14.71 	Epsilon: 0.14300635237083656
# target updating
# Episode 390	Reward -16.0 	Average Score: -14.76 	Epsilon: 0.14157986400593744
# target updating
# Episode 391	Reward -14.0 	Average Score: -14.73 	Epsilon: 0.14087196468590776
# target updating
# Episode 392	Reward -8.0 	Average Score: -14.71 	Epsilon: 0.14016760486247823
# target updating
# Episode 394	Reward -13.0 	Average Score: -14.58 	Epsilon: 0.138769433003975
# target updating
# Episode 395	Reward -15.0 	Average Score: -14.59 	Epsilon: 0.13807558583895513
# target updating
# Episode 397	Reward -14.0 	Average Score: -14.47 	Epsilon: 0.13669828187021155
# target updating
# Episode 398	Reward -12.0 	Average Score: -14.48 	Epsilon: 0.13601479046086049
# target updating
# Episode 400	Average Score: -14.44 	Epsilon: 0.1346580429260134
#
# target updating
# Episode 402	Reward -19.0 	Average Score: -14.41 	Epsilon: 0.13331482894782642
# target updating
# Episode 403	Reward -15.0 	Average Score: -14.40 	Epsilon: 0.13264825480308728
# target updating
# Episode 404	Reward -13.0 	Average Score: -14.37 	Epsilon: 0.13198501352907185
# target updating
# Episode 405	Reward -10.0 	Average Score: -14.46 	Epsilon: 0.1313250884614265
# target updating
# Episode 407	Reward -12.0 	Average Score: -14.36 	Epsilon: 0.13001512070402377
# target updating
# Episode 409	Reward -11.0 	Average Score: -14.35 	Epsilon: 0.12871821987500112
# target updating
# Episode 410	Reward -5.0 	Average Score: -14.23 	Epsilon: 0.12807462877562611
# target updating
# Episode 411	Reward -15.0 	Average Score: -14.27 	Epsilon: 0.12743425563174798
# target updating
# Episode 413	Reward -10.0 	Average Score: -14.13 	Epsilon: 0.1261630989318213
# target updating
# Episode 414	Reward -15.0 	Average Score: -14.12 	Epsilon: 0.1255322834371622
# target updating
# Episode 416	Reward -18.0 	Average Score: -14.16 	Epsilon: 0.1242800989098765
# target updating
# Episode 417	Reward -15.0 	Average Score: -14.12 	Epsilon: 0.12365869841532712
# target updating
# Episode 418	Reward -8.0 	Average Score: -14.04 	Epsilon: 0.12304040492325048
# target updating
# Episode 419	Reward -12.0 	Average Score: -14.01 	Epsilon: 0.12242520289863423
# target updating
# Episode 420	Reward -6.0 	Average Score: -13.88 	Epsilon: 0.12181307688414106
# target updating
# Episode 421	Reward -12.0 	Average Score: -13.94 	Epsilon: 0.12120401149972035
# target updating
# Episode 423	Reward -9.0 	Average Score: -13.79 	Epsilon: 0.11999500148501063
# target updating
# Episode 424	Reward -8.0 	Average Score: -13.74 	Epsilon: 0.11939502647758558
# target updating
# Episode 425	Reward -8.0 	Average Score: -13.66 	Epsilon: 0.11879805134519765
# target updating
# Episode 426	Reward -5.0 	Average Score: -13.51 	Epsilon: 0.11820406108847166
# target updating
# Episode 427	Reward -9.0 	Average Score: -13.45 	Epsilon: 0.1176130407830293
# target updating
# Episode 429	Reward -8.0 	Average Score: -13.21 	Epsilon: 0.11643985070121858
# target updating
# Episode 430	Reward 1.0 	Average Score: -13.05 	Epsilon: 0.11585765144771248
# target updating
# Episode 431	Reward -7.0 	Average Score: -13.00 	Epsilon: 0.11527836319047392
# target updating
# Episode 432	Reward -13.0 	Average Score: -12.99 	Epsilon: 0.11470197137452155
# target updating
# Episode 433	Reward -11.0 	Average Score: -12.97 	Epsilon: 0.11412846151764894
# target updating
# Episode 435	Reward -13.0 	Average Score: -12.82 	Epsilon: 0.11299003011401039
# target updating
# Episode 436	Reward -7.0 	Average Score: -12.71 	Epsilon: 0.11242507996344034
# target updating
# Episode 437	Reward 12.0 	Average Score: -12.43 	Epsilon: 0.11186295456362313
# target updating
# Episode 438	Reward 5.0 	Average Score: -12.29 	Epsilon: 0.11130363979080501
# target updating
# Episode 440	Reward 7.0 	Average Score: -11.76 	Epsilon: 0.11019338598389174
# target updating
# Episode 442	Reward 8.0 	Average Score: -11.68 	Epsilon: 0.10909420695870241
# target updating
# Episode 443	Reward -11.0 	Average Score: -11.66 	Epsilon: 0.1085487359239089
# target updating
# Episode 444	Reward 10.0 	Average Score: -11.38 	Epsilon: 0.10800599224428936
# target updating
# Episode 446	Reward -11.0 	Average Score: -11.14 	Epsilon: 0.10692863247165257
# target updating
# Episode 447	Reward 3.0 	Average Score: -10.94 	Epsilon: 0.1063939893092943
# target updating
# Episode 448	Reward 14.0 	Average Score: -10.65 	Epsilon: 0.10586201936274783
# target updating
# Episode 449	Reward 1.0 	Average Score: -10.48 	Epsilon: 0.10533270926593409
# target updating
# Episode 450	Reward -6.0 	Average Score: -10.38 	Epsilon: 0.10480604571960442
# target updating
# Episode 452	Reward 4.0 	Average Score: -10.07 	Epsilon: 0.10376060541355137
# target updating
# Episode 453	Reward 4.0 	Average Score: -9.94 	Epsilon: 0.1032418023864836
# target updating
# Episode 454	Reward 6.0 	Average Score: -9.77 	Epsilon: 0.10272559337455119
# target updating
# Episode 455	Reward 8.0 	Average Score: -9.58 	Epsilon: 0.10221196540767843
# target updating
# Episode 457	Reward -10.0 	Average Score: -9.23 	Epsilon: 0.10119240105273684
# target updating
# Episode 459	Reward 15.0 	Average Score: -8.73 	Epsilon: 0.10018300685223579
# target updating
# Episode 460	Reward -5.0 	Average Score: -8.65 	Epsilon: 0.0996820918179746
# target updating
# Episode 462	Reward 6.0 	Average Score: -8.41 	Epsilon: 0.09868776295209031
# target updating
# Episode 463	Reward -7.0 	Average Score: -8.32 	Epsilon: 0.09819432413732986
# target updating
# Episode 464	Reward 11.0 	Average Score: -8.07 	Epsilon: 0.09770335251664321
# target updating
# Episode 465	Reward 9.0 	Average Score: -7.86 	Epsilon: 0.09721483575406
# target updating
# Episode 467	Reward -15.0 	Average Score: -7.77 	Epsilon: 0.09624511776741324
# target updating
# Episode 468	Reward 6.0 	Average Score: -7.58 	Epsilon: 0.09576389217857617
# target updating
# Episode 469	Reward 10.0 	Average Score: -7.33 	Epsilon: 0.09528507271768329
# target updating
# Episode 471	Reward 15.0 	Average Score: -6.87 	Epsilon: 0.0943346041173244
# target updating
# Episode 472	Reward 11.0 	Average Score: -6.63 	Epsilon: 0.09386293109673778
# target updating
# Episode 473	Reward -7.0 	Average Score: -6.52 	Epsilon: 0.09339361644125409
# target updating
# Episode 474	Reward 6.0 	Average Score: -6.36 	Epsilon: 0.09292664835904782
# target updating
# Episode 475	Reward 1.0 	Average Score: -6.19 	Epsilon: 0.09246201511725258
# target updating
# Episode 476	Reward -14.0 	Average Score: -6.15 	Epsilon: 0.09199970504166631
# target updating
# Episode 478	Reward 18.0 	Average Score: -5.68 	Epsilon: 0.09108200798387568
# target updating
# Episode 480	Reward -7.0 	Average Score: -5.34 	Epsilon: 0.09017346495423652
# target updating
# Episode 481	Reward 15.0 	Average Score: -5.04 	Epsilon: 0.08972259762946533
# target updating
# Episode 483	Reward 8.0 	Average Score: -4.49 	Epsilon: 0.0888276147181114
# target updating
# Episode 484	Reward 3.0 	Average Score: -4.29 	Epsilon: 0.08838347664452084
# target updating
# Episode 485	Reward 11.0 	Average Score: -4.01 	Epsilon: 0.08794155926129824
# target updating
# Episode 486	Reward -1.0 	Average Score: -3.85 	Epsilon: 0.08750185146499175
# target updating
# Episode 488	Reward -10.0 	Average Score: -3.65 	Epsilon: 0.08662902049662846
# target updating
# Episode 489	Reward 10.0 	Average Score: -3.38 	Epsilon: 0.08619587539414532
# target updating
# Episode 491	Reward -9.0 	Average Score: -3.03 	Epsilon: 0.08533607153708872
# target updating
# Episode 492	Reward 13.0 	Average Score: -2.82 	Epsilon: 0.08490939117940327
# target updating
# Episode 494	Reward -7.0 	Average Score: -2.55 	Epsilon: 0.08406242000238873
# target updating
# Episode 495	Reward 5.0 	Average Score: -2.35 	Epsilon: 0.08364210790237678
# target updating
# Episode 496	Reward -5.0 	Average Score: -2.31 	Epsilon: 0.0832238973628649
# target updating
# Episode 498	Reward -13.0 	Average Score: -2.30 	Epsilon: 0.08239373898667031
# target updating
# Episode 499	Reward -1.0 	Average Score: -2.18 	Epsilon: 0.08198177029173696
# target updating
# Episode 500	Average Score: -2.17 	Epsilon: 0.08157186144027828
#
# target updating
# Episode 502	Reward -9.0 	Average Score: -2.05 	Epsilon: 0.08075818212241151
# target updating
# Episode 503	Reward -14.0 	Average Score: -2.04 	Epsilon: 0.08035439121179945
# target updating
# Episode 504	Reward -8.0 	Average Score: -1.99 	Epsilon: 0.07995261925574046
# target updating
# Episode 505	Reward -4.0 	Average Score: -1.93 	Epsilon: 0.07955285615946175
# target updating
# Episode 507	Reward 3.0 	Average Score: -1.73 	Epsilon: 0.07875931641927113
# target updating
# Episode 508	Reward 15.0 	Average Score: -1.39 	Epsilon: 0.07836551983717477
# target updating
# Episode 509	Reward -14.0 	Average Score: -1.42 	Epsilon: 0.07797369223798889
# target updating
# Episode 510	Reward 2.0 	Average Score: -1.35 	Epsilon: 0.07758382377679894
# target updating
# Episode 512	Reward -11.0 	Average Score: -1.25 	Epsilon: 0.07680992513462537
# target updating
# Episode 514	Reward -16.0 	Average Score: -1.32 	Epsilon: 0.07604374613140748
# target updating
# Episode 516	Reward 8.0 	Average Score: -1.04 	Epsilon: 0.07528520976374668
# target updating
# Episode 517	Reward -2.0 	Average Score: -0.91 	Epsilon: 0.07490878371492794
# target updating
# Episode 518	Reward -2.0 	Average Score: -0.85 	Epsilon: 0.0745342397963533
# target updating
# Episode 519	Reward -1.0 	Average Score: -0.74 	Epsilon: 0.07416156859737154
# target updating
# Episode 521	Reward -10.0 	Average Score: -0.70 	Epsilon: 0.07342180695061275
# target updating
# Episode 522	Reward 6.0 	Average Score: -0.59 	Epsilon: 0.07305469791585968
# target updating
# Episode 524	Reward 14.0 	Average Score: -0.18 	Epsilon: 0.07232597730414898
# target updating
# Episode 526	Reward 15.0 	Average Score: 0.22 	Epsilon: 0.0716045256805401
# target updating
# Episode 527	Reward 14.0 	Average Score: 0.45 	Epsilon: 0.0712465030521374
# target updating
# Episode 529	Reward 14.0 	Average Score: 0.85 	Epsilon: 0.07053581918419231
# target updating
# Episode 530	Reward 3.0 	Average Score: 0.87 	Epsilon: 0.07018314008827135
# target updating
# Episode 531	Reward -16.0 	Average Score: 0.78 	Epsilon: 0.06983222438783
# target updating
# Episode 533	Reward 20.0 	Average Score: 1.14 	Epsilon: 0.0691356479495614
# target updating
# Episode 535	Reward 16.0 	Average Score: 1.52 	Epsilon: 0.06844601986126451
# target updating
# Episode 536	Reward 11.0 	Average Score: 1.70 	Epsilon: 0.06810378976195819
# target updating
# Episode 538	Reward 13.0 	Average Score: 1.76 	Epsilon: 0.06742445445908266
# target updating
#
# target updating
# Episode 540	Reward 8.0 	Average Score: 1.66 	Epsilon: 0.0667518955258533
# target updating
# Episode 542	Reward 20.0 	Average Score: 2.16 	Epsilon: 0.0660860453679829
# target updating
# Episode 544	Reward 16.0 	Average Score: 2.49 	Epsilon: 0.06542683706543727
# target updating
# Episode 545	Reward 10.0 	Average Score: 2.53 	Epsilon: 0.06509970288011008
# target updating
# Episode 547	Reward 20.0 	Average Score: 2.95 	Epsilon: 0.06445033334388098
# target updating
# Episode 548	Reward 13.0 	Average Score: 2.94 	Epsilon: 0.06412808167716157
# target updating
# Episode 550	Reward 13.0 	Average Score: 3.10 	Epsilon: 0.06348840406243188
# target updating
# Episode 551	Reward 10.0 	Average Score: 3.18 	Epsilon: 0.06317096204211972
# target updating
# Episode 553	Reward 12.0 	Average Score: 3.36 	Epsilon: 0.06254083169574957
# target updating
# Episode 555	Reward 18.0 	Average Score: 3.50 	Epsilon: 0.06191698689958447
# target updating
# Episode 556	Reward 14.0 	Average Score: 3.54 	Epsilon: 0.061607401965086545
# target updating
# Episode 558	Reward 19.0 	Average Score: 3.91 	Epsilon: 0.0609928681304848
# target updating
# Episode 560	Reward 18.0 	Average Score: 4.07 	Epsilon: 0.06038446427088321
# target updating
# Episode 561	Reward 11.0 	Average Score: 4.31 	Epsilon: 0.06008254194952879
# target updating
# Episode 563	Reward 20.0 	Average Score: 4.70 	Epsilon: 0.05948321859358224
# target updating
# Episode 564	Reward 18.0 	Average Score: 4.77 	Epsilon: 0.05918580250061433
# target updating
# Episode 566	Reward 13.0 	Average Score: 4.73 	Epsilon: 0.058595424120670696
# target updating
# Episode 567	Reward -11.0 	Average Score: 4.77 	Epsilon: 0.05830244700006734
# target updating
# Episode 569	Reward 20.0 	Average Score: 4.86 	Epsilon: 0.05772088009124167
# target updating
# Episode 571	Reward 13.0 	Average Score: 4.75 	Epsilon: 0.05714511431233153
# target updating
# Episode 572	Reward 13.0 	Average Score: 4.77 	Epsilon: 0.05685938874076987
# target updating
# Episode 574	Reward -10.0 	Average Score: 4.78 	Epsilon: 0.056292216338080694
# target updating
# Episode 576	Reward 11.0 	Average Score: 5.17 	Epsilon: 0.05573070148010834
# target updating
# Episode 578	Reward 18.0 	Average Score: 5.36 	Epsilon: 0.05517478773284426
# target updating
# Episode 580	Reward 15.0 	Average Score: 5.60 	Epsilon: 0.05462441922520914
# target updating
# Episode 581	Reward 2.0 	Average Score: 5.47 	Epsilon: 0.0543512971290831
# target updating
# Episode 583	Reward 15.0 	Average Score: 5.57 	Epsilon: 0.05380914294022049
# target updating
# Episode 585	Reward 19.0 	Average Score: 5.72 	Epsilon: 0.05327239673939179
# target updating
# Episode 586	Reward 13.0 	Average Score: 5.86 	Epsilon: 0.053006034755694834
# target updating
# Episode 588	Reward 8.0 	Average Score: 6.13 	Epsilon: 0.052477299559006776
# target updating
# Episode 590	Reward 17.0 	Average Score: 6.00 	Epsilon: 0.05195383849590569
# target updating
# Episode 591	Reward 16.0 	Average Score: 6.25 	Epsilon: 0.05169406930342616
# target updating
# Episode 593	Reward 8.0 	Average Score: 6.12 	Epsilon: 0.051178420962124486
# target updating
# Episode 595	Reward 20.0 	Average Score: 6.53 	Epsilon: 0.05066791621302729
# target updating
# Episode 597	Reward 15.0 	Average Score: 7.02 	Epsilon: 0.050162503748802344
# target updating
# Episode 599	Reward 18.0 	Average Score: 7.53 	Epsilon: 0.04966213277390804
# target updating
# Episode 600	Average Score: 7.87 	Epsilon: 0.0494138221100385
# Episode 601	Reward 18.0 	Average Score: 8.18 	Epsilon: 0.04916675299948831
# target updating
# Episode 603	Reward 16.0 	Average Score: 8.77 	Epsilon: 0.04867631463831842
# target updating
# Episode 604	Reward 6.0 	Average Score: 8.91 	Epsilon: 0.048432933065126825
# target updating
# Episode 606	Reward 17.0 	Average Score: 9.38 	Epsilon: 0.04794981455780219
# target updating
# Episode 608	Reward 15.0 	Average Score: 9.49 	Epsilon: 0.047471515157588115
# target updating
# Episode 610	Reward 18.0 	Average Score: 9.97 	Epsilon: 0.046997986793891174
# target updating
# Episode 612	Reward 17.0 	Average Score: 10.48 	Epsilon: 0.04652918187562211
# target updating
# Episode 614	Reward 21.0 	Average Score: 11.19 	Epsilon: 0.046065053286412784
# target updating
# Episode 616	Reward 15.0 	Average Score: 11.59 	Epsilon: 0.045605554379880814
# target updating
# Episode 617	Reward 12.0 	Average Score: 11.73 	Epsilon: 0.04537752660798141
# target updating
# Episode 619	Reward 14.0 	Average Score: 12.05 	Epsilon: 0.044924885780066794
# target updating
# Episode 622	Reward 21.0 	Average Score: 12.73 	Epsilon: 0.04425437624418858
# target updating
# Episode 624	Reward 16.0 	Average Score: 12.81 	Epsilon: 0.043812938841152796
# target updating
# Episode 625	Reward 18.0 	Average Score: 12.87 	Epsilon: 0.04359387414694703
# target updating
# Episode 627	Reward 17.0 	Average Score: 12.89 	Epsilon: 0.043159025252331236
# target updating
# Episode 629	Reward 20.0 	Average Score: 12.98 	Epsilon: 0.04272851397543923
# target updating
# Episode 630	Reward 3.0 	Average Score: 12.98 	Epsilon: 0.04251487140556204
# target updating
# Episode 631	Reward 16.0 	Average Score: 13.30 	Epsilon: 0.04230229704853423
# target updating
# Episode 632	Reward 1.0 	Average Score: 13.39 	Epsilon: 0.04209078556329156
# target updating
# Episode 634	Reward 9.0 	Average Score: 13.27 	Epsilon: 0.041670929977297724
# target updating
# Episode 635	Reward 11.0 	Average Score: 13.22 	Epsilon: 0.04146257532741124
# target updating
# Episode 637	Reward 18.0 	Average Score: 13.20 	Epsilon: 0.04104898613852031
# target updating
# Episode 638	Reward 7.0 	Average Score: 13.14 	Epsilon: 0.04084374120782771
# target updating
# Episode 640	Reward 16.0 	Average Score: 13.25 	Epsilon: 0.04043632488927963
# target updating
# Episode 642	Reward 20.0 	Average Score: 13.16 	Epsilon: 0.040032972548509065
# target updating
# Episode 644	Reward -10.0 	Average Score: 12.90 	Epsilon: 0.03963364364733769
# target updating
# Episode 646	Reward 17.0 	Average Score: 13.02 	Epsilon: 0.03923829805195549
# target updating
# Episode 647	Reward 17.0 	Average Score: 12.99 	Epsilon: 0.03904210656169572
# target updating
# Episode 649	Reward 18.0 	Average Score: 13.13 	Epsilon: 0.0386526615487428
# target updating
# Episode 651	Reward 17.0 	Average Score: 13.24 	Epsilon: 0.03826710124979409
# target updating
# Episode 653	Reward 19.0 	Average Score: 13.28 	Epsilon: 0.0378853869148274
# target updating
# Episode 654	Reward 13.0 	Average Score: 13.31 	Epsilon: 0.03769595998025326
# target updating
# Episode 656	Reward 11.0 	Average Score: 13.24 	Epsilon: 0.037319942779450235
# target updating
# Episode 658	Reward 9.0 	Average Score: 13.16 	Epsilon: 0.03694767635022522
# target updating
# Episode 659	Reward 7.0 	Average Score: 13.15 	Epsilon: 0.036762937968474095
# target updating
# Episode 661	Reward 20.0 	Average Score: 13.19 	Epsilon: 0.036396227662238566
# target updating
# Episode 664	Reward 20.0 	Average Score: 13.15 	Epsilon: 0.03585300941485119
# target updating
# Episode 665	Reward 20.0 	Average Score: 13.44 	Epsilon: 0.035673744367776934
# target updating
# Episode 667	Reward 17.0 	Average Score: 13.67 	Epsilon: 0.035317898767708356
# target updating
# Episode 669	Reward 13.0 	Average Score: 13.71 	Epsilon: 0.03496560272750046
# target updating
# Episode 671	Reward 21.0 	Average Score: 14.02 	Epsilon: 0.03461682084029365
# target updating
# Episode 673	Reward 17.0 	Average Score: 14.15 	Epsilon: 0.034271518052411715
